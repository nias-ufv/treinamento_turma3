# %%
import pandas as pd

# %%
#1
p = pd.read_csv(r"C:\Users\cliente\Downloads\covid\covid_19_clean_complete.csv")

# %%
display(p)
cpia=p
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
print("The number of rows and columns is", p.shape)
# Out:
# The number of rows and columns is (49068, 10)

# %%
print("The columns is", p.columns)
# Out:
# The columns is Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
#c

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
#substituindo o formato de uma coluna object para datetime
#pd.to_datetime(pd.Series(["Jul 31, 2009", "2010-01-10", None]))
p["Date"] = p["Date"].astype('datetime64')

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB

# %%
#informações estatisticas

# %%
display(p.describe())
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
#Coluna especifica que mostra uma coluna com itens vazios

# %%
display(p.loc[:, p.isna().any()])
# Out:
#       Province/State
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 49063            NaN
# 49064            NaN
# 49065            NaN
# 49066            NaN
# 49067            NaN
#
# [49068 rows x 1 columns]

# %%
#2#coluna espec

# %%
vou = p.loc[p["Country/Region"] == 'China', ['Province/State','Country/Region', 'Lat', 'Long', 'Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'WHO Region']]

# %%
display(vou)
# Out:
#       Province/State Country/Region      Lat      Long       Date  Confirmed  \
# 48             Anhui          China  31.8257  117.2264 2020-01-22          1
# 49           Beijing          China  40.1824  116.4142 2020-01-22         14
# 50         Chongqing          China  30.0572  107.8740 2020-01-22          6
# 51            Fujian          China  26.0789  117.9874 2020-01-22          1
# 52             Gansu          China  35.7518  104.2861 2020-01-22          0
# ...              ...            ...      ...       ...        ...        ...
# 48883        Tianjin          China  39.3054  117.3230 2020-07-27        204
# 48884          Tibet          China  31.6927   88.0924 2020-07-27          1
# 48885       Xinjiang          China  41.1129   85.2401 2020-07-27        311
# 48886         Yunnan          China  24.9740  101.4870 2020-07-27        190
# 48887       Zhejiang          China  29.1832  120.0934 2020-07-27       1270
#
# ...

# %%
#Tome apenas as informações das features: “Confirmed”, “Active”, “Deaths”,
#“Recovered”

# %%
y = p.loc[p["Country/Region"] == 'China', [ 'Province/State','Confirmed', 'Deaths', 'Recovered', 'Active']]

# %%
display(y)
# Out:
#       Province/State  Confirmed  Deaths  Recovered  Active
# 48             Anhui          1       0          0       1
# 49           Beijing         14       0          0      14
# 50         Chongqing          6       0          0       6
# 51            Fujian          1       0          0       1
# 52             Gansu          0       0          0       0
# ...              ...        ...     ...        ...     ...
# 48883        Tianjin        204       3        195       6
# 48884          Tibet          1       0          1       0
# 48885       Xinjiang        311       3         73     235
# 48886         Yunnan        190       2        186       2
# 48887       Zhejiang       1270       1       1268       1
#
# [6204 rows x 5 columns]

# %%
#apagar as linhas iguais

# %%
y= y.drop_duplicates(subset='Confirmed', keep='first')
display(y)
# Out:
#        Province/State  Confirmed  Deaths  Recovered  Active
# 48              Anhui          1       0          0       1
# 49            Beijing         14       0          0      14
# 50          Chongqing          6       0          0       6
# 52              Gansu          0       0          0       0
# 53          Guangdong         26       0          0      26
# ...               ...        ...     ...        ...     ...
# 48606       Hong Kong       2633      18       1495    1120
# 48609  Inner Mongolia        258       1        244      13
# 48856         Beijing        931       9        895      27
# 48867       Hong Kong       2778      22       1486    1270
# 48880        Shanghai        743       7        718      18
#
# [965 rows x 5 columns]

# %%
x= y.drop_duplicates(subset='Confirmed', keep='first')
display(x)
# Out:
#        Province/State  Confirmed  Deaths  Recovered  Active
# 48              Anhui          1       0          0       1
# 49            Beijing         14       0          0      14
# 50          Chongqing          6       0          0       6
# 52              Gansu          0       0          0       0
# 53          Guangdong         26       0          0      26
# ...               ...        ...     ...        ...     ...
# 48606       Hong Kong       2633      18       1495    1120
# 48609  Inner Mongolia        258       1        244      13
# 48856         Beijing        931       9        895      27
# 48867       Hong Kong       2778      22       1486    1270
# 48880        Shanghai        743       7        718      18
#
# [965 rows x 5 columns]

# %%
#pegar o maior valor de linhas com mesmos nomes

# %%
q = y.groupby('Province/State', sort=False).max().sort_values('Confirmed', ascending=False)

# %%
display(q.head(5))
# Out:
#                 Confirmed  Deaths  Recovered  Active
# Province/State
# Hubei               68135    4512      63762   50633
# Hong Kong            2778      22       1495    1270
# Guangdong            1672       8       1642     991
# Henan                1276      22          0    1254
# Zhejiang             1269       1       1267     883

# %%
#3#juntando duas colunas e excluindo quem é NaN
#w=vou["Country/Region"] = vou["Country/Region"] + "_" + vou["Province/State"]

# %%
#kop = p.dropna()

# %%
#display(kop)

# %%
#LEMBRAR#vou.loc[vou['Country/Region'] = vou['Country/Region'] + '_' + vou['Province/State'] , [ 'Province/State','Confirmed', 'Deaths', 'Recovered', 'Active']]

# %%
#Juntando as linhas de duas colunas
#kop['Country/Region']=kop["Country/Region"] + "_" + kop["Province/State"]
#display(kop[['Country/Region', 'Lat', 'Long', 'Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'WHO Region']])

# %%
#juntando as linhas de duas colunas 
#p['Country/Region']=p["Country/Region"] + "_" + p["Province/State"]
#display(p[['Country/Region', 'Lat', 'Long', 'Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'WHO Region']])

# %%
#funcao que soma as linhas da coluna (str) ignorando os espacos vazios da coluna, mas mostrando a soma sem os vazios
p.columns = p.columns.str.replace('/','')
teste=p

# %%
def soml(l):
    if pd.isnull(l.ProvinceState) == False:
        l.CountryRegion = l.CountryRegion + '_' + l.ProvinceState
    return(l)
cp=teste.apply(soml, axis=1)
cp= cp.drop('ProvinceState', axis=1)
display(cp)
cp.head(10)
# Out:
#                CountryRegion        Lat       Long       Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953 2020-01-22          0
# 1                    Albania  41.153300  20.168300 2020-01-22          0
# 2                    Algeria  28.033900   1.659600 2020-01-22          0
# 3                    Andorra  42.506300   1.521800 2020-01-22          0
# 4                     Angola -11.202700  17.873900 2020-01-22          0
# ...                      ...        ...        ...        ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100 2020-07-27        865
# 49064                  Yemen  15.552727  48.516388 2020-07-27       1691
# 49065                Comoros -11.645500  43.333300 2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100 2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600 2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region
# ...

# %%
#4
z = pd.read_csv(r"C:\Users\cliente\Downloads\worldometer_data.csv")
display(z[['Country/Region', 'Continent', 'Population']])
# Out:
#             Country/Region      Continent    Population
# 0                      USA  North America  3.311981e+08
# 1                   Brazil  South America  2.127107e+08
# 2                    India           Asia  1.381345e+09
# 3                   Russia         Europe  1.459409e+08
# 4             South Africa         Africa  5.938157e+07
# ..                     ...            ...           ...
# 204             Montserrat  North America  4.992000e+03
# 205  Caribbean Netherlands  North America  2.624700e+04
# 206       Falkland Islands  South America  3.489000e+03
# 207           Vatican City         Europe  8.010000e+02
# 208         Western Sahara         Africa  5.986820e+05
#
# [209 rows x 3 columns]

# %%
rt=z.groupby('Continent', sort=False).sum('TotalDeaths').sort_values('TotalDeaths', ascending=False)

# %%
rt['TotalDeaths/1M']= (rt['TotalDeaths']*1000000)/rt['Population']
display(rt[['Population', 'TotalDeaths/1M']])
# Out:
#                      Population  TotalDeaths/1M
# Continent
# North America      5.895035e+08      389.912889
# Europe             7.476775e+08      274.492662
# South America      4.311105e+08      359.269869
# Asia               3.173656e+09       31.706961
# Africa             1.343515e+09       16.459803
# Australia/Oceania  4.095791e+07        6.860702
